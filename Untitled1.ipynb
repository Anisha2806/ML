# %% [markdown]
# <a href="https://colab.research.google.com/github/Anisha2806/ML/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/FDSA PROGRAMS/DATA SET/uber-rides-dataset.csv')
df

# %%
df.shape
# Out:
# (678, 45)

# %%
df.info()

# %%
df.describe()

# %%
df.columns
# Out:
# Index(['Posted On', 'BHK', 'Rent', 'Size', 'Floor', 'Area Type',
#        'Area Locality', 'City', 'Furnishing Status', 'Tenant Preferred',
#        'Bathroom', 'Point of Contact'],
#       dtype='object')

# %%
df.duplicated()

# %%
df.head(2)
# Out:
#         trip_completed_at trip_status ride_hailing_app  \
# 0  May 11, 2015 at 6:55PM   Completed             Uber
# 1  May 11, 2015 at 8:12PM   Completed             Uber
#
#                            trip_uid                        driver_uid  \
# 0  ee89076fd9da9bddf5f096b0ca42f8d5  05cfeb269e606247fe9d2b6082942c59
# 1  518be51d403944a03c47e8d1f2c87311  4a4e248742f9d5ff517c5bbbb48d0e54
#
#                           rider_uid  customer  trip_start_time  \
# 0  3ffa4a71a5aa791a8bc3409f5b15b936  stantyan  5/11/2015 17:26
# 1  3ffa4a71a5aa791a8bc3409f5b15b936  stantyan  5/11/2015 18:46
#
#      trip_end_time trip_time  ... distance_kms     temperature_time  \
# 0  5/11/2015 17:55   0:21:33  ...         9.29  2015-05-11T17:26:00
# 1  5/11/2015 19:12   0:19:27  ...         9.93  2015-05-11T18:46:00
#
#   temperature_value  feels_like humidity wind_speed cloudness  \
# 0                12          12     0.69       4.81      0.78
# ...

# %%
X=df[['trip_time','distance_kms']]
y=df[['price_rub']]
X
# Out:
#     trip_time  distance_kms
# 0     0:21:33          9.29
# 1     0:19:27          9.93
# 2     1:06:53         18.01
# 3     0:13:37          5.10
# 4     0:38:54         21.92
# ..        ...           ...
# 673   0:10:37          5.79
# 674   0:23:41         11.46
# 675   0:16:20          6.68
# 676   0:19:19          7.48
# 677   0:32:46          9.03
#
# [678 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder
X['distance_kms']=LabelEncoder().fit_transform(X['distance_kms'])
X['trip_time']=LabelEncoder().fit_transform(X['trip_time'])

# %%
X['distance_kms']
# Out:
# 0      273
# 1      289
# 2      415
# 3      131
# 4      434
#       ...
# 673    159
# 674    328
# 675    196
# 676    223
# 677    267
# Name: distance_kms, Length: 678, dtype: int64

# %%
X['trip_time']
# Out:
# 0      348
# 1      311
# 2      567
# 3      165
# 4      520
#       ...
# 673     97
# 674    374
# 675    235
# 676    309
# 677    485
# Name: trip_time, Length: 678, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=(X,y,test_size=0.3,random_state=42)
